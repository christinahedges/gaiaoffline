# %% [markdown]
# # Example usage
#
# This notebook shows a quick example of how to use the `gaiaoffline` package. You should follow the installation instructions for the package that include setting up the offline database.

# %%
from gaiaoffline import Gaia

# %%
with Gaia() as gaia:
    results = gaia.conesearch(ra=45.0, dec=6.0, radius=0.5)

# %%
results
# Out:
#             source_id         ra       dec  parallax       pmra      pmdec  \
# 0    7090720423502592  44.509845  5.929635  0.747558   6.432207   4.551372
# 1    7097317492675328  44.519449  6.081799  4.258604   5.068064   5.079538
# 2    7097317493262720  44.519675  6.081777       NaN        NaN        NaN
# 3    7096905176403968  44.525031  6.043208  0.081763  -0.017625  -2.614324
# 4    7103188712818304  44.526470  6.097983  1.191807   7.503639 -10.218165
# ..                ...        ...       ...       ...        ...        ...
# 334  6983380600824704  45.458557  6.067333  4.926242  11.960269 -54.369694
# 335  6969636705444736  45.465496  5.838977  1.581406   0.013144 -11.781949
# 336  6996918337697024  45.469726  6.172912  1.219428   7.261278 -16.497606
# 337  6976852250498432  45.493519  5.914465  0.652126  -1.255462  -4.339768
# 338  6976852249883520  45.493727  5.914622       NaN        NaN        NaN
#
# ...
